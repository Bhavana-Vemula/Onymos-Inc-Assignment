# %%
import random
import threading
import time

# %%
class Order:
    def __init__(self, order_type, ticker, quantity, price):
        self.order_type = order_type  # "Buy" or "Sell"
        self.ticker = ticker          # e.g. "T123"
        self.quantity = quantity
        self.price = price

    def __str__(self):
        return f"Order({self.order_type}, {self.ticker}, Q:{self.quantity}, P:{self.price})"

class OrderBook:
    def __init__(self):
        # Lists of orders for the given ticker.
        self.buy_orders = []   # Buy orders list
        self.sell_orders = []  # Sell orders list

# %%
# Preallocate an array of 1024 order books.
# Each index corresponds to a ticker “T<index>” where index in [0,1023]
order_books = [OrderBook() for _ in range(1024)]

# %%
def getTickerIndex(ticker):
    """
    Convert ticker symbol (assumed to be of the form "T<number>") 
    to an index for order_books.
    """
    # Example: ticker "T500" returns integer 500.
    return int(ticker[1:])

# ----------------------------
# Order handling functions
# ----------------------------

def addOrder(order_type, ticker, quantity, price):
    """
    Add an order to the order book.
    
    Parameters:
      order_type (str): "Buy" or "Sell"
      ticker (str): Ticker symbol (e.g., "T123")
      quantity (int): Number of shares
      price (float): Price per share
    """
    index = getTickerIndex(ticker)
    order = Order(order_type, ticker, quantity, price)
    # Append the order to the proper list (simulate lock-free insertion)
    if order_type == "Buy":
        order_books[index].buy_orders.append(order)
    elif order_type == "Sell":
        order_books[index].sell_orders.append(order)
    print("Added order:", order)

def matchOrder(ticker):
    """
    Match Buy and Sell orders for a given ticker.
    
    Matching criteria:
      - If the best (lowest) Sell order price is less than or equal to a Buy order's price,
        the orders are matched.
      - Partial fills are supported.
      
    Time complexity: O(n) where n is the number of orders in the ticker’s order book.
    """
    index = getTickerIndex(ticker)
    book = order_books[index]
    
    # Continue matching as long as a valid match exists.
    while True:
        # Find the lowest-priced Sell order (linear scan: O(n))
        lowest_sell = None
        lowest_sell_index = -1
        for i, sell in enumerate(book.sell_orders):
            if sell is not None:
                if lowest_sell is None or sell.price < lowest_sell.price:
                    lowest_sell = sell
                    lowest_sell_index = i
        
        # No sell orders available → nothing to match
        if lowest_sell is None:
            break
        
        # Look for a Buy order that can match the lowest Sell order.
        matched = False
        for j, buy in enumerate(book.buy_orders):
            if buy is not None and buy.price >= lowest_sell.price:
                # Determine traded quantity (supporting partial fills)
                traded_quantity = min(buy.quantity, lowest_sell.quantity)
                print("Matching:", buy, "with", lowest_sell, f"for Q:{traded_quantity}")
                
                # Update quantities after trade
                buy.quantity -= traded_quantity
                lowest_sell.quantity -= traded_quantity
                
                # Mark orders for removal if fully filled.
                if buy.quantity == 0:
                    book.buy_orders[j] = None
                if lowest_sell.quantity == 0:
                    book.sell_orders[lowest_sell_index] = None
                
                matched = True
                break
        

        if not matched:
            break

        book.buy_orders = [o for o in book.buy_orders if o is not None]
        book.sell_orders = [o for o in book.sell_orders if o is not None]

# %%
running = True

def simulate_add_orders():
    """
    Simulate active stock transactions by randomly adding orders.
    """
    while running:
        order_type = random.choice(["Buy", "Sell"])
        # Generate a ticker from T0 to T1023.
        ticker = "T" + str(random.randint(0, 1023))
        quantity = random.randint(1, 100)
        price = round(random.uniform(10, 1000), 2)
        addOrder(order_type, ticker, quantity, price)
        # Sleep briefly to simulate real-time order arrivals.
        time.sleep(0.01)

def simulate_match_orders():
    """
    Continuously try to match orders for random tickers.
    """
    while running:
        ticker = "T" + str(random.randint(0, 1023))
        matchOrder(ticker)
        # Sleep briefly between matching attempts.
        time.sleep(0.01)

# %%
# ----------------------------
# Start the simulation with multiple threads.
# ----------------------------

threads = []
t1 = threading.Thread(target=simulate_add_orders)
t2 = threading.Thread(target=simulate_match_orders)
threads.append(t1)
threads.append(t2)

t1.start()
t2.start()

# Run simulation for a fixed period (e.g., 5 seconds)
time.sleep(5)
running = False

# Wait for threads to finish
for t in threads:
    t.join()

print("Simulation complete.")
# Out:
# Added order: Order(Sell, T812, Q:55, P:946.72)
# Added order: Order(Sell, T845, Q:1, P:793.49)
# Added order: Order(Sell, T743, Q:87, P:84.34)
# Added order: Order(Buy, T841, Q:27, P:967.77)
# Added order: Order(Sell, T542, Q:82, P:587.28)
# Added order: Order(Sell, T365, Q:23, P:276.29)
# Added order: Order(Sell, T343, Q:24, P:482.49)
# Added order: Order(Sell, T42, Q:19, P:941.66)
# Added order: Order(Sell, T714, Q:83, P:854.07)
# Added order: Order(Sell, T1022, Q:14, P:946.31)
# Added order: Order(Buy, T466, Q:51, P:84.05)
# Added order: Order(Buy, T755, Q:7, P:54.1)
# Added order: Order(Sell, T832, Q:24, P:828.05)
# Added order: Order(Buy, T1007, Q:48, P:481.39)
# Added order: Order(Sell, T697, Q:96, P:450.87)
# Added order: Order(Sell, T298, Q:52, P:346.94)
# Added order: Order(Buy, T340, Q:67, P:121.47)
# Added order: Order(Sell, T99, Q:25, P:770.24)
# Added order: Order(Sell, T912, Q:37, P:463.91)
# Added order: Order(Buy, T649, Q:46, P:758.65)
# Added order: Order(Sell, T235, Q:18, P:303.69)
# Added order: Order(Sell, T41, Q:58, P:669.31)
# Added order: Order(Sell, T577, Q:27, P:783.15)
# Added order: Order(Sell, T22, Q:48, P:173.16)
# Added order: Order(Sell, T204, Q:42, P:966.96)
# Added order: Order(Buy, T284, Q:50, P:346.51)
# Added order: Order(Buy, T805, Q:37, P:173.09)
# Added order: Order(Sell, T580, Q:53, P:733.09)
# Added order: Order(Sell, T387, Q:92, P:506.34)
# Added order: Order(Buy, T797, Q:13, P:57.9)
# Added order: Order(Buy, T845, Q:37, P:848.21)
# Added order: Order(Sell, T59, Q:66, P:46.17)
# Added order: Order(Sell, T877, Q:48, P:627.28)
# Added order: Order(Sell, T747, Q:57, P:682.66)
# Added order: Order(Buy, T180, Q:38, P:588.72)
# Added order: Order(Buy, T201, Q:47, P:717.61)
# Added order: Order(Buy, T1011, Q:78, P:559.2)
# Added order: Order(Sell, T890, Q:8, P:419.55)
# Added order: Order(Buy, T251, Q:32, P:433.82)
# Added order: Order(Buy, T226, Q:62, P:844.16)
# Added order: Order(Sell, T812, Q:31, P:706.41)
# Added order: Order(Sell, T826, Q:74, P:289.78)
# Added order: Order(Buy, T165, Q:43, P:307.24)
# Added order: Order(Buy, T832, Q:2, P:870.44)
# Added order: Order(Buy, T269, Q:90, P:18.06)
# Added order: Order(Buy, T248, Q:11, P:304.55)
# Added order: Order(Buy, T264, Q:59, P:836.67)
# Added order: Order(Sell, T821, Q:13, P:626.3)
# Added order: Order(Buy, T899, Q:52, P:706.71)
# Added order: Order(Sell, T236, Q:75, P:955.35)
# Added order: Order(Sell, T240, Q:63, P:206.89)
# Added order: Order(Sell, T190, Q:3, P:858.44)
# Added order: Order(Buy, T213, Q:2, P:105.41)
# Added order: Order(Buy, T573, Q:54, P:258.78)
# Added order: Order(Buy, T980, Q:40, P:522.5)
# Added order: Order(Buy, T106, Q:87, P:620.54)
# Added order: Order(Sell, T38, Q:100, P:423.9)
# Added order: Order(Sell, T1000, Q:4, P:455.38)
# Added order: Order(Sell, T143, Q:57, P:602.77)
# Added order: Order(Sell, T160, Q:91, P:785.59)
# Added order: Order(Buy, T159, Q:13, P:808.62)
# Added order: Order(Sell, T325, Q:73, P:855.63)
# Added order: Order(Buy, T787, Q:68, P:190.78)
# Added order: Order(Sell, T933, Q:53, P:432.28)
# Added order: Order(Buy, T254, Q:69, P:814.85)
# Added order: Order(Buy, T504, Q:56, P:284.1)
# Added order: Order(Buy, T296, Q:19, P:33.46)
# Added order: Order(Buy, T341, Q:43, P:10.03)
# Added order: Order(Sell, T727, Q:82, P:851.75)
# Added order: Order(Sell, T90, Q:96, P:167.53)
# Added order: Order(Sell, T256, Q:63, P:185.68)
# Added order: Order(Buy, T630, Q:71, P:542.23)
# Added order: Order(Sell, T736, Q:78, P:250.84)
# Added order: Order(Sell, T102, Q:79, P:590.17)
# Added order: Order(Sell, T832, Q:61, P:328.08)
# Added order: Order(Buy, T715, Q:67, P:918.87)
# Added order: Order(Sell, T127, Q:83, P:560.52)
# Added order: Order(Buy, T852, Q:95, P:285.09)
# Added order: Order(Sell, T508, Q:68, P:592.25)
# Added order: Order(Sell, T352, Q:94, P:801.21)
# Added order: Order(Buy, T638, Q:100, P:154.92)
# Added order: Order(Buy, T787, Q:79, P:483.06)
# Added order: Order(Sell, T52, Q:42, P:956.51)
# Added order: Order(Sell, T879, Q:69, P:89.22)
# Added order: Order(Buy, T973, Q:54, P:997.81)
# Added order: Order(Sell, T622, Q:4, P:478.7)
# Added order: Order(Buy, T690, Q:48, P:949.57)
# Added order: Order(Buy, T892, Q:41, P:926.16)
# Added order: Order(Sell, T682, Q:59, P:313.32)
# Added order: Order(Sell, T628, Q:43, P:238.87)
# Added order: Order(Sell, T166, Q:69, P:953.97)
# Added order: Order(Sell, T70, Q:16, P:839.89)
# Added order: Order(Buy, T272, Q:84, P:402.82)
# Added order: Order(Buy, T568, Q:15, P:304.76)
# Added order: Order(Sell, T487, Q:88, P:692.1)
# Added order: Order(Sell, T0, Q:4, P:996.96)
# Added order: Order(Sell, T266, Q:63, P:437.61)
# Added order: Order(Buy, T115, Q:21, P:404.05)
# Added order: Order(Sell, T825, Q:6, P:983.58)
# Added order: Order(Sell, T950, Q:73, P:575.11)
# Added order: Order(Sell, T698, Q:21, P:635.24)
# Added order: Order(Sell, T429, Q:47, P:187.82)
# Added order: Order(Buy, T550, Q:100, P:319.34)
# Added order: Order(Sell, T416, Q:16, P:80.82)
# Added order: Order(Buy, T595, Q:66, P:821.5)
# Added order: Order(Sell, T994, Q:53, P:673.85)
# Added order: Order(Buy, T808, Q:67, P:710.12)
# Added order: Order(Sell, T572, Q:42, P:360.59)
# Added order: Order(Buy, T783, Q:34, P:356.16)
# Added order: Order(Sell, T221, Q:72, P:644.67)
# Added order: Order(Buy, T707, Q:12, P:729.7)
# Added order: Order(Sell, T191, Q:23, P:870.22)
# Added order: Order(Sell, T800, Q:83, P:490.36)
# Added order: Order(Sell, T331, Q:95, P:889.26)
# Added order: Order(Buy, T862, Q:99, P:157.29)
# Added order: Order(Buy, T428, Q:69, P:872.23)
# Added order: Order(Sell, T367, Q:44, P:788.43)
# Added order: Order(Sell, T598, Q:65, P:188.98)
# Added order: Order(Buy, T162, Q:90, P:568.7)
# Added order: Order(Sell, T728, Q:86, P:716.39)
# Added order: Order(Sell, T823, Q:74, P:431.19)
# Added order: Order(Buy, T18, Q:52, P:917.65)
# Added order: Order(Sell, T821, Q:53, P:445.04)
# Added order: Order(Sell, T810, Q:83, P:275.67)
# Added order: Order(Sell, T237, Q:92, P:95.85)
# Added order: Order(Buy, T445, Q:83, P:919.2)
# Added order: Order(Sell, T519, Q:42, P:917.0)
# Added order: Order(Sell, T47, Q:12, P:810.71)
# Added order: Order(Buy, T954, Q:68, P:262.31)
# Added order: Order(Buy, T363, Q:33, P:908.59)
# Added order: Order(Buy, T427, Q:38, P:936.57)
# Added order: Order(Sell, T415, Q:85, P:193.99)
# Added order: Order(Buy, T140, Q:40, P:253.81)
# Added order: Order(Buy, T329, Q:18, P:930.26)
# Added order: Order(Buy, T64, Q:7, P:738.01)
# Added order: Order(Buy, T755, Q:79, P:460.71)
# Added order: Order(Sell, T198, Q:93, P:809.73)
# Added order: Order(Buy, T67, Q:49, P:426.28)
# Added order: Order(Sell, T517, Q:9, P:773.02)
# Added order: Order(Sell, T218, Q:46, P:817.57)
# Added order: Order(Sell, T385, Q:32, P:955.23)
# Added order: Order(Buy, T514, Q:42, P:712.08)
# Added order: Order(Buy, T93, Q:75, P:615.94)
# Added order: Order(Buy, T140, Q:53, P:154.74)
# Added order: Order(Sell, T84, Q:98, P:505.79)
# Added order: Order(Buy, T612, Q:46, P:657.64)
# Added order: Order(Sell, T854, Q:89, P:533.41)
# Added order: Order(Sell, T82, Q:64, P:283.72)
# Added order: Order(Sell, T715, Q:69, P:964.7)
# Added order: Order(Buy, T359, Q:84, P:480.93)
# Added order: Order(Sell, T137, Q:67, P:409.83)
# Added order: Order(Sell, T878, Q:59, P:790.63)
# Added order: Order(Buy, T767, Q:17, P:359.55)
# Added order: Order(Buy, T631, Q:67, P:660.47)
# Added order: Order(Sell, T347, Q:86, P:319.13)
# Added order: Order(Buy, T446, Q:5, P:141.33)
# Added order: Order(Buy, T928, Q:90, P:654.25)
# Added order: Order(Buy, T698, Q:31, P:122.97)
# Added order: Order(Buy, T311, Q:30, P:562.61)
# Added order: Order(Buy, T912, Q:55, P:789.87)
# Added order: Order(Buy, T281, Q:53, P:709.39)
# Added order: Order(Buy, T470, Q:53, P:573.58)
# Added order: Order(Sell, T244, Q:78, P:729.17)
# Added order: Order(Sell, T947, Q:27, P:151.26)
# Added order: Order(Sell, T62, Q:89, P:664.59)
# Added order: Order(Buy, T899, Q:6, P:787.37)
# Added order: Order(Sell, T848, Q:77, P:557.39)
# Added order: Order(Buy, T922, Q:8, P:220.31)
# Added order: Order(Buy, T749, Q:93, P:736.18)
# Added order: Order(Sell, T589, Q:85, P:725.05)
# Added order: Order(Buy, T831, Q:59, P:641.65)
# Added order: Order(Buy, T312, Q:22, P:61.0)
# Added order: Order(Sell, T805, Q:30, P:299.29)
# Added order: Order(Buy, T480, Q:97, P:591.93)
# Added order: Order(Sell, T684, Q:99, P:913.9)
# Added order: Order(Sell, T723, Q:91, P:542.14)
# Added order: Order(Buy, T991, Q:16, P:246.04)
# Added order: Order(Sell, T871, Q:77, P:671.74)
# Added order: Order(Buy, T694, Q:97, P:731.68)
# Added order: Order(Sell, T378, Q:87, P:544.37)
# Added order: Order(Buy, T345, Q:76, P:197.53)
# Added order: Order(Buy, T958, Q:11, P:106.43)
# Added order: Order(Buy, T584, Q:80, P:792.91)
# Added order: Order(Sell, T858, Q:66, P:612.17)
# Added order: Order(Sell, T399, Q:97, P:492.52)
# Added order: Order(Buy, T678, Q:11, P:633.25)
# Added order: Order(Buy, T963, Q:25, P:94.87)
# Added order: Order(Buy, T342, Q:73, P:367.19)
# Added order: Order(Sell, T864, Q:60, P:954.31)
# Added order: Order(Sell, T172, Q:58, P:185.24)
# Added order: Order(Sell, T473, Q:37, P:624.37)
# Added order: Order(Buy, T221, Q:56, P:806.03)
# Added order: Order(Buy, T656, Q:14, P:922.19)
# Added order: Order(Buy, T795, Q:29, P:329.04)
# Added order: Order(Buy, T226, Q:30, P:850.84)
# Added order: Order(Sell, T123, Q:83, P:148.94)
# Added order: Order(Buy, T360, Q:12, P:843.45)
# Added order: Order(Buy, T521, Q:50, P:32.02)
# Added order: Order(Buy, T38, Q:100, P:839.41)
# Added order: Order(Sell, T831, Q:84, P:930.09)
# Added order: Order(Sell, T612, Q:83, P:755.61)
# Added order: Order(Buy, T621, Q:5, P:423.68)
# Added order: Order(Sell, T213, Q:33, P:319.05)
# Matching: Order(Buy, T912, Q:55, P:789.87) with Order(Sell, T912, Q:37, P:463.91) for Q:37
# Added order: Order(Buy, T632, Q:31, P:607.5)
# Added order: Order(Sell, T168, Q:67, P:228.55)
# Added order: Order(Buy, T210, Q:53, P:114.49)
# Added order: Order(Sell, T178, Q:21, P:699.15)
# Added order: Order(Sell, T994, Q:94, P:214.27)
# Added order: Order(Sell, T758, Q:50, P:940.99)
# Added order: Order(Buy, T92, Q:78, P:919.25)
# Added order: Order(Sell, T607, Q:80, P:789.69)
# Added order: Order(Sell, T690, Q:83, P:764.91)
# Added order: Order(Sell, T1000, Q:2, P:438.82)
# Added order: Order(Sell, T662, Q:44, P:698.02)
# Added order: Order(Sell, T342, Q:73, P:581.25)
# Added order: Order(Buy, T660, Q:48, P:398.64)
# Added order: Order(Sell, T907, Q:81, P:196.92)
# Added order: Order(Sell, T54, Q:58, P:611.99)
# Added order: Order(Sell, T960, Q:98, P:924.92)
# Added order: Order(Sell, T16, Q:4, P:248.1)
# Added order: Order(Sell, T29, Q:68, P:261.14)
# Added order: Order(Sell, T130, Q:88, P:247.21)
# Added order: Order(Sell, T765, Q:27, P:685.5)
# Added order: Order(Buy, T234, Q:47, P:337.5)
# Added order: Order(Buy, T589, Q:18, P:99.4)
# Added order: Order(Buy, T654, Q:3, P:80.1)
# Added order: Order(Sell, T440, Q:63, P:667.53)
# Added order: Order(Sell, T554, Q:46, P:640.49)
# Added order: Order(Buy, T670, Q:74, P:523.27)
# Matching: Order(Buy, T832, Q:2, P:870.44) with Order(Sell, T832, Q:61, P:328.08) for Q:2
# Added order: Order(Sell, T943, Q:42, P:603.8)
# Added order: Order(Buy, T709, Q:23, P:209.47)
# Added order: Order(Sell, T470, Q:22, P:997.3)
# Added order: Order(Buy, T403, Q:30, P:50.6)
# Added order: Order(Buy, T528, Q:37, P:299.96)
# Added order: Order(Sell, T600, Q:2, P:861.96)
# Added order: Order(Sell, T806, Q:18, P:394.74)
# Added order: Order(Sell, T337, Q:9, P:141.31)
# Added order: Order(Buy, T584, Q:5, P:824.12)
# Added order: Order(Sell, T651, Q:26, P:17.88)
# Added order: Order(Sell, T30, Q:33, P:681.08)
# Added order: Order(Buy, T467, Q:51, P:793.58)
# Added order: Order(Buy, T141, Q:7, P:608.91)
# Added order: Order(Sell, T96, Q:7, P:978.61)
# Added order: Order(Sell, T563, Q:84, P:715.81)
# Added order: Order(Sell, T57, Q:15, P:710.51)
# Added order: Order(Sell, T973, Q:40, P:93.97)
# Added order: Order(Buy, T927, Q:28, P:178.35)
# Added order: Order(Sell, T850, Q:86, P:865.03)
# Added order: Order(Sell, T285, Q:23, P:906.46)
# Added order: Order(Buy, T907, Q:31, P:592.93)
# Added order: Order(Sell, T825, Q:7, P:348.15)
# Added order: Order(Buy, T508, Q:100, P:17.84)
# Added order: Order(Buy, T555, Q:100, P:706.75)
# Added order: Order(Buy, T785, Q:38, P:636.36)
# Added order: Order(Sell, T329, Q:16, P:248.0)
# Added order: Order(Sell, T943, Q:98, P:830.29)
# Added order: Order(Sell, T146, Q:32, P:865.74)
# Added order: Order(Sell, T587, Q:12, P:587.27)
# Added order: Order(Sell, T277, Q:87, P:113.81)
# Added order: Order(Sell, T897, Q:40, P:425.28)
# Added order: Order(Buy, T90, Q:97, P:770.0)
# Added order: Order(Sell, T612, Q:31, P:890.38)
# Added order: Order(Sell, T91, Q:18, P:981.0)
# Added order: Order(Buy, T80, Q:17, P:688.93)
# Added order: Order(Sell, T322, Q:53, P:937.73)
# Added order: Order(Sell, T91, Q:47, P:856.96)
# Added order: Order(Sell, T38, Q:68, P:498.84)
# Added order: Order(Sell, T802, Q:80, P:223.88)
# Added order: Order(Buy, T896, Q:55, P:705.71)
# Added order: Order(Buy, T790, Q:15, P:748.32)
# Added order: Order(Buy, T671, Q:4, P:489.31)
# Added order: Order(Sell, T307, Q:73, P:99.12)
# Added order: Order(Sell, T8, Q:10, P:176.9)
# Added order: Order(Buy, T847, Q:77, P:483.55)
# Added order: Order(Sell, T411, Q:52, P:544.04)
# Added order: Order(Sell, T528, Q:12, P:615.92)
# Added order: Order(Buy, T264, Q:84, P:57.73)
# Added order: Order(Buy, T629, Q:20, P:42.12)
# Added order: Order(Sell, T910, Q:8, P:355.4)
# Added order: Order(Buy, T358, Q:93, P:716.9)
# Added order: Order(Buy, T366, Q:93, P:48.82)
# Added order: Order(Buy, T793, Q:80, P:490.61)
# Added order: Order(Sell, T743, Q:27, P:122.79)
# Added order: Order(Buy, T145, Q:16, P:14.53)
# Added order: Order(Buy, T700, Q:85, P:17.13)
# Added order: Order(Buy, T961, Q:45, P:992.47)
# Added order: Order(Buy, T152, Q:16, P:340.56)
# Added order: Order(Buy, T627, Q:73, P:954.27)
# Added order: Order(Buy, T197, Q:70, P:480.46)
# Added order: Order(Sell, T231, Q:39, P:255.12)
# Added order: Order(Buy, T205, Q:60, P:998.83)
# Added order: Order(Buy, T102, Q:2, P:197.8)
# Added order: Order(Sell, T682, Q:57, P:450.89)
# Added order: Order(Sell, T17, Q:27, P:169.51)
# Added order: Order(Buy, T687, Q:7, P:398.14)
# Added order: Order(Buy, T521, Q:31, P:862.0)
# Added order: Order(Buy, T54, Q:9, P:119.51)
# Added order: Order(Sell, T1021, Q:76, P:121.73)
# Added order: Order(Buy, T186, Q:70, P:818.11)
# Added order: Order(Buy, T25, Q:6, P:950.16)
# Added order: Order(Sell, T551, Q:100, P:873.48)
# Added order: Order(Buy, T602, Q:46, P:109.42)
# Added order: Order(Buy, T100, Q:42, P:172.01)
# Added order: Order(Sell, T724, Q:44, P:312.0)
# Added order: Order(Sell, T589, Q:60, P:115.95)
# Added order: Order(Sell, T583, Q:46, P:557.03)
# Added order: Order(Sell, T248, Q:8, P:990.46)
# Added order: Order(Buy, T381, Q:59, P:881.69)
# Added order: Order(Sell, T904, Q:93, P:232.12)
# Added order: Order(Sell, T983, Q:50, P:49.01)
# Added order: Order(Buy, T943, Q:43, P:204.27)
# Added order: Order(Sell, T891, Q:50, P:744.1)
# Added order: Order(Buy, T248, Q:2, P:66.0)
# Added order: Order(Buy, T509, Q:87, P:470.32)
# Added order: Order(Sell, T925, Q:5, P:665.83)
# Added order: Order(Buy, T858, Q:44, P:669.07)
# Added order: Order(Buy, T703, Q:26, P:546.57)
# Added order: Order(Sell, T271, Q:18, P:153.84)
# Added order: Order(Sell, T892, Q:89, P:961.15)
# Added order: Order(Sell, T498, Q:35, P:528.84)
# Added order: Order(Buy, T362, Q:70, P:459.95)
# Added order: Order(Buy, T781, Q:25, P:365.87)
# Added order: Order(Buy, T180, Q:27, P:680.28)
# Added order: Order(Sell, T586, Q:68, P:437.37)
# Added order: Order(Sell, T342, Q:62, P:764.09)
# Added order: Order(Sell, T41, Q:23, P:947.85)
# Added order: Order(Buy, T873, Q:78, P:98.11)
# Added order: Order(Buy, T363, Q:75, P:887.25)
# Added order: Order(Sell, T612, Q:95, P:702.23)
# Added order: Order(Sell, T137, Q:82, P:558.5)
# Added order: Order(Buy, T122, Q:45, P:126.12)
# Added order: Order(Buy, T681, Q:97, P:737.31)
# Added order: Order(Sell, T723, Q:18, P:514.07)
# Added order: Order(Sell, T478, Q:66, P:194.29)
# Added order: Order(Buy, T678, Q:19, P:751.32)
# Added order: Order(Buy, T844, Q:92, P:437.84)
# Added order: Order(Sell, T34, Q:99, P:173.83)
# Added order: Order(Sell, T358, Q:32, P:34.18)
# Added order: Order(Sell, T937, Q:42, P:958.58)
# Added order: Order(Buy, T894, Q:94, P:199.7)
# Added order: Order(Sell, T350, Q:32, P:811.61)
# Added order: Order(Buy, T665, Q:67, P:185.16)
# Added order: Order(Sell, T416, Q:50, P:383.08)
# Added order: Order(Sell, T1017, Q:54, P:839.23)
# Added order: Order(Buy, T352, Q:52, P:496.33)
# Added order: Order(Sell, T721, Q:39, P:142.37)
# Added order: Order(Buy, T1017, Q:62, P:426.61)
# Added order: Order(Sell, T148, Q:37, P:55.73)
# Added order: Order(Sell, T521, Q:78, P:150.17)
# Added order: Order(Buy, T474, Q:80, P:508.02)
# Added order: Order(Sell, T256, Q:81, P:404.36)
# Added order: Order(Buy, T72, Q:79, P:981.05)
# Added order: Order(Sell, T932, Q:39, P:759.11)
# Added order: Order(Sell, T309, Q:100, P:599.84)
# Added order: Order(Sell, T176, Q:78, P:19.55)
# Added order: Order(Buy, T536, Q:97, P:541.55)
# Added order: Order(Buy, T25, Q:95, P:502.23)
# Added order: Order(Sell, T443, Q:71, P:744.39)
# Added order: Order(Buy, T719, Q:90, P:922.16)
# Added order: Order(Buy, T679, Q:75, P:678.55)
# Added order: Order(Buy, T31, Q:11, P:330.24)
# Added order: Order(Sell, T970, Q:40, P:935.45)
# Added order: Order(Buy, T374, Q:39, P:294.85)
# Added order: Order(Sell, T1023, Q:14, P:867.71)
# Added order: Order(Buy, T388, Q:75, P:573.99)
# Added order: Order(Sell, T396, Q:16, P:478.77)
# Added order: Order(Buy, T11, Q:37, P:328.15)
# Added order: Order(Buy, T258, Q:90, P:942.83)
# Added order: Order(Sell, T674, Q:46, P:751.59)
# Added order: Order(Buy, T451, Q:85, P:885.4)
# Added order: Order(Sell, T382, Q:47, P:268.83)
# Added order: Order(Buy, T594, Q:38, P:988.37)
# Added order: Order(Sell, T376, Q:91, P:767.31)
# Added order: Order(Sell, T227, Q:27, P:735.27)
# Added order: Order(Sell, T206, Q:42, P:235.98)
# Added order: Order(Buy, T949, Q:89, P:784.75)
# Added order: Order(Sell, T688, Q:29, P:749.73)
# Added order: Order(Buy, T870, Q:55, P:895.76)
# Added order: Order(Sell, T142, Q:44, P:479.32)
# Added order: Order(Buy, T923, Q:36, P:474.9)
# Added order: Order(Buy, T756, Q:24, P:113.59)
# Added order: Order(Buy, T5, Q:40, P:354.77)
# Added order: Order(Buy, T328, Q:83, P:11.26)
# Added order: Order(Buy, T624, Q:78, P:70.45)
# Added order: Order(Buy, T593, Q:88, P:691.65)
# Added order: Order(Sell, T273, Q:92, P:357.54)
# Added order: Order(Buy, T996, Q:72, P:843.96)
# Added order: Order(Sell, T561, Q:94, P:109.0)
# Added order: Order(Buy, T151, Q:13, P:571.98)
# Added order: Order(Sell, T302, Q:25, P:806.08)
# Added order: Order(Buy, T696, Q:20, P:243.51)
# Added order: Order(Sell, T918, Q:44, P:118.69)
# Added order: Order(Sell, T213, Q:70, P:338.96)
# Added order: Order(Sell, T358, Q:5, P:685.26)
# Added order: Order(Sell, T780, Q:52, P:856.52)
# Added order: Order(Buy, T602, Q:6, P:797.41)
# Added order: Order(Sell, T659, Q:7, P:306.11)
# Added order: Order(Buy, T818, Q:6, P:432.25)
# Added order: Order(Sell, T533, Q:60, P:918.53)
# Added order: Order(Sell, T128, Q:78, P:118.41)
# Added order: Order(Sell, T200, Q:47, P:470.42)
# Added order: Order(Sell, T143, Q:61, P:891.28)
# Added order: Order(Sell, T614, Q:10, P:758.89)
# Added order: Order(Buy, T24, Q:99, P:343.21)
# Added order: Order(Buy, T294, Q:65, P:421.79)
# Added order: Order(Buy, T758, Q:34, P:534.45)
# Added order: Order(Buy, T980, Q:24, P:912.37)
# Added order: Order(Buy, T846, Q:21, P:472.54)
# Added order: Order(Sell, T86, Q:42, P:142.84)
# Added order: Order(Sell, T6, Q:17, P:485.23)
# Added order: Order(Buy, T115, Q:15, P:438.14)
# Added order: Order(Buy, T747, Q:78, P:699.01)
# Added order: Order(Sell, T91, Q:70, P:674.11)
# Simulation complete.
